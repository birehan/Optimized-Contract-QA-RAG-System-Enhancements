# %%
import json

def extract_json(file_path):
    try:
        with open(file_path, 'r', encoding='utf-8') as file:
            data = json.load(file)
        return data
    except Exception as e:
        print(f"An error occurred while extracting JSON data: {e}")
        return None

# Example usage:
file_path = "../data/prepare_policy_data/data/qa_with_context/dev.json"

json_data = extract_json(file_path)
if json_data:
    print("JSON data extracted successfully!")
    # Do further processing with the extracted JSON data
    # For example, print the content:
    print(json_data)
else:
    print("Failed to extract JSON data.")
# Out:
# JSON data extracted successfully!
# {'version': 'v1.0', 'data': [{'title': 'ticketmaster.com', 'paragraphs': [{'qas': [{'question': 'How does this website inform users about their policy changes?', 'type': 'Policy Change|||Notification Type|||General notice in privacy policy', 'id': 'ctnk84gy3t6wdijv', 'answers': [{'text': 'Effective July 20, 2012 (last updated October 08, 2013)', 'answer_start': 63}]}], 'index': 0, 'context': 'Live Nation Entertainment Privacy Policy - Your Privacy Rights Effective July 20, 2012 (last updated October 08, 2013)'}, {'qas': [{'question': 'Does the privacy policy mention about the data practice for interantional audiences?', 'type': 'International and Specific Audiences|||Audience Type|||Citizens from other countries', 'id': 'jmti4stsogolp49z', 'answers': [{'text': 'If you live in Canada, please read our Canadian Privacy Policy.', 'answer_start': 294}]}], 'index': 1, 'context': 'This Privacy Policy applies to the sites and apps where it appears. This Policy describes how we treat personal information we collect both online and offline. This includes on our websites or in our apps. It also includes at our box offices or in phone or email interactions you have with us. If you live in Canada, please read our Canadian Privacy Policy.'}, {'qas': [{'question': 'Do you ask for my contact information?', 'type': 'First Party Collection/Use|||Personal Information Type|||Contact', 'id': 'el20m9l5wj8fq2om', 'answers': [{'text': 'Contact information. For example, we might collect your name and street address. We might also collect your phone number or email.', 'answer_start': 43}, {'text': 'name and street address. We might also collect your phone number or email.', 'answer_start': 99}]}, {'question': 'Does the collected data reveal my identity?', 'type': 'First Party Collection/Use|||Identifiability|||Identifiable', 'id': 'x3elyri8l6ol3zqr', 'answers': [{'text': 'name and street address', 'answer_start': 99}]}, {'question': 'Will they use the data collected from me?', 'type': 'First Party Collection/Use|||Does/Does Not|||Does', 'id': 'hezwq0unnhmezwlw', 'answers': [{'text': 'We collect information from and about you.', 'answer_start': 0}]}], 'index': 2, 'context': 'We collect information from and about you. Contact information. For example, we might collect your name and street address. We might also collect your phone number or email.'}, {'qas': [{'question': "Does the company collect user's financial information?", 'type': 'First Party Collection/Use|||Personal Information Type|||Financial', 'id': 'i1matwosph3owqln', 'answers': [{'text': 'Payment and billing information. For example, we collect your credit card number and zip code when you buy a ticket.', 'answer_start': 0}, {'text': 'credit card number and zip code', 'answer_start': 62}]}, {'question': 'Does the website provide any choices to users for data collection?', 'type': 'First Party Collection/Use|||Choice Scope|||Collection', 'id': 'hp3z0slx1qkejssd', 'answers': [{'text': 'collect', 'answer_start': 49}]}, {'question': 'Will you collect my data? If yes, how?', 'type': 'First Party Collection/Use|||Action First-Party|||Other', 'id': 'v883988zklkj8bfe', 'answers': [{'text': 'when you buy a ticket', 'answer_start': 94}]}, {'question': 'Do I need to give up privacy control to use your service?', 'type': 'First Party Collection/Use|||Choice Type|||Dont use service/feature', 'id': '8vv9g4kcjv90vbw7', 'answers': [{'text': 'when you buy a ticket.', 'answer_start': 94}]}, {'question': 'Does this website collect my information?', 'type': 'First Party Collection/Use|||Does/Does Not|||Does', 'id': 'wxoo1ii57ap6xerx', 'answers': [{'text': 'we collect your credit card number', 'answer_start': 46}]}, {'question': 'For what purpose do you use my data?', 'type': 'First Party Collection/Use|||Purpose|||Basic service/feature', 'id': 'jpfv8krobtqfpoox', 'answers': [{'text': 'buy a ticket.', 'answer_start': 103}]}], 'index': 3, 'context': 'Payment and billing information. For example, we collect your c ...

# %%
json_data
# Out:
# {'version': 'v1.0',
#  'data': [{'title': 'ticketmaster.com',
#    'paragraphs': [{'qas': [{'question': 'How does this website inform users about their policy changes?',
#        'type': 'Policy Change|||Notification Type|||General notice in privacy policy',
#        'id': 'ctnk84gy3t6wdijv',
#        'answers': [{'text': 'Effective July 20, 2012 (last updated October 08, 2013)',
#          'answer_start': 63}]}],
#      'index': 0,
#      'context': 'Live Nation Entertainment Privacy Policy - Your Privacy Rights Effective July 20, 2012 (last updated October 08, 2013)'},
#     {'qas': [{'question': 'Does the privacy policy mention about the data practice for interantional audiences?',
#        'type': 'International and Specific Audiences|||Audience Type|||Citizens from other countries',
#        'id': 'jmti4stsogolp49z',
#        'answers': [{'text': 'If you live in Canada, please read our Canadian Privacy Policy.',
#          'answer_start': 294}]}],
#      'index': 1,
#      'context': 'This Privacy Policy applies to the sites and apps where it appears. This Policy describes how we treat personal information we collect both online and offline. This includes on our websites or in our apps. It also includes at our box offices or in phone or email interactions you have with us. If you live in Canada, please read our Canadian Privacy Policy.'},
#     {'qas': [{'question': 'Do you ask for my contact information?',
#        'type': 'First Party Collection/Use|||Personal Information Type|||Contact',
#        'id': 'el20m9l5wj8fq2om',
#        'answers': [{'text': 'Contact information. For example, we might collect your name and street address. We might also collect your phone number or email.',
#          'answer_start': 43},
#         {'text': 'name and street address. We might also collect your phone number or email.',
#          'answer_start': 99}]},
#       {'question': 'Does the collected data reveal my identity?',
#        'type': 'First Party Collection/Use|||Identifiability|||Identifiable',
#        'id': 'x3elyri8l6ol3zqr',
#        'answers': [{'text': 'name and street address', 'answer_start': 99}]},
#       {'question': 'Will they use the data collected from me?',
#        'type': 'First Party Collection/Use|||Does/Does Not|||Does',
#        'id': 'hezwq0unnhmezwlw',
#        'answers': [{'text': 'We collect information from and about you.',
#          'answer_start': 0}]}],
#      'index': 2,
#      'context': 'We collect information from and about you. Contact information. For example, we might collect your name and street address. We might also collect your phone number or email.'},
#     {'qas': [{'question': "Does the company collect user's financial information?",
#        'type': 'First Party Collection/Use|||Personal Information Type|||Financial',
#        'id': 'i1matwosph3owqln',
#        'answers': [{'text': 'Payment and billing information. For example, we collect your credit card number and zip code when you buy a ticket.',
#          'answer_start': 0},
#         {'text': 'credit card number and zip code', 'answer_start': 62}]},
#       {'question': 'Does the website provide any choices to users for data collection?',
#        'type': 'First Party Collection/Use|||Choice Scope|||Collection',
#        'id': 'hp3z0slx1qkejssd',
#        'answers': [{'text': 'collect', 'answer_start': 49}]},
#       {'question': 'Will you collect my data? If yes, how?',
#        'type': 'First Party Collection/Use|||Action First-Party|||Other',
#        'id': 'v883988zklkj8bfe',
#        'answers': [{'text': 'when you buy a ticket', 'answer_start': 94}]},
#       {'question': 'Do I need to give up privacy control to use your service?',
#        'type': 'First Party Collection/Use|||Choice Type|||Dont use service/feature',
#        'id': '8vv9g4kcjv90vbw7',
#        'answers': [{'text': 'when you buy a ticket.', 'answer_start': 94}]},
#       {'question': 'Does this website collect my information?',
#        'type': 'First Party Collection/Use|||Does/Does Not|||Does',
#        'id': 'wxoo1ii57ap6xerx',
#        'answers': [{'text': 'we collect your credit card number',
#          'answer_start': 46}]},
#       {'question': 'For what purpose do you use my data?',
#        'type': 'First Party Collection/Use|||Purpose|||Basic service/feature',
#        'id': 'jpfv8krobtqfpoox',
#        'answers': [{'text': 'buy a ticket.', 'answer_start': 103}]}],
#      'index': 3,
#      'context': 'Payment and billing information. For example, we collect your credit card number and zip code when you buy a ticket.'},
#     {'qas': [{'question': 'What is the choice scope for users with regards to first party data collection?',
#        'type': 'First Party Collection/Use|||Choice Scope|||Collection',
#        'id': 'eplxx3whxemxs8oc',
#        'answers': [{'text': 'collect', 'answer_start': 38}]},
#       {'question': 'Where do you collect my information?',
#        'type': 'First Party Collection/Use|||Action First-Party|||Collect on website',
#        'id': 'hok8glgmaxuss2hq',
#        'answers': [{'text': 'we collect information you post in a public space on our website',
#          'answer_start': 35}]},
#       {'question': 'Will you give me control over your data collection or use?',
#        'type': 'First Party Collection/Use|||Choice Type|||Dont use service/feature',
#        'id': 'kem34fmbzuggp2h9',
#        'answers': [{'text': 'Information you post', 'answer_start': 0}]},
#       {'question': 'Does this website collect my information?',
#        'type': 'First Party Collection/Use|||Does/Does Not|||Does',
#        'id': 'vtnxyjwvd1iu3909',
#        'answers': [{'text': 'we collect information', 'answer_start': 35}]},
#       {'question': 'Do you receive my data from other companies? ',
#        'type': 'First Party Collection/Use|||Action First-Party|||Receive from other service/third-party (unnamed)',
#        'id': 'd12p236hr3mclhmj',
#        'answers': [{'text': 'third-party social media site.',
#          'answer_start': 108},
#         {'text': 'on a third-party social media site', 'answer_start': 103}]},
#       {'question': 'What type of personal info does the company collect about me?',
#        'type': 'First Party Collection/Use|||Personal Information Type|||Social media data',
#        'id': '7rbicc832zwk85oh',
#        'answers': [{'text': 'Information you post. For example, we collect information you post in a public space on our website or on a third-party social media site.',
#          'answer_start': 0},
#         {'text': 'on a third-party social media site', 'answer_start': 103}]},
#       {'question': "Does the company keep track of users' profile info?",
#        'type': 'First Party Collection/Use|||Personal Information Type|||User profile',
#        'id': 'l2k37mgnss2lctad',
#        'answers': [{'text': 'information you post in a public space',
#          'answer_start': 46}]}],
#      'index': 4,
#      'context': 'Information you post. For example, we collect information you post in a public space on our website or on a third-party social media site.'},
#     {'qas': [{'question': 'Do you keep a record of my demographic information?',
#        'type': 'First Party Collection/Use|||Personal Information Type|||Demographic',
#        'id': '5mrz9xjdyvx2jcey',
#        'answers': [{'text': 'Demographic information. We may collect information about events you like or products you buy.',
#          'answer_start': 0},
#         {'text': 'Demographic information. We may collect information about events you like or products you buy. We might collect this as part of a survey, for example.',
#          'answer_start': 0}]},
#       {'question': 'Will they use the data collected from me?',
#        'type': 'First Party Collection/Use|||Does/Does Not|||Does',
#        'id': 'xhkkny28e47wy57z',
#        'answers': [{'text': 'We may collect information',
#          'answer_start': 25}]},
#       {'question': 'Do you collect data about users explicitly?',
#        'type': 'First Party Collection/Use|||Collection Mode|||Explicit',
#        'id': 'me5r3z7v28n8luqa',
#        'answers': [{'text': 'We might collect this as part of a survey',
#          'answer_start': 95}]}],
#      'index': 5,
#      'context': 'Demographic information. We may collect information about events you like or products you buy. We might collect this as part of a survey, for example.'},
#     {'qas': [{'question': 'Does the website provide any choices to users for data collection?',
#        'type': 'First Party Collection/Use|||Choice Scope|||Collection',
#        'id': 'mb8ayzz84n94focd',
#        'answers': [{'text': 'collect', 'answer_start': 50}]},
#       {'question': "Does the company collect user's information directly on their website?",
#        'type': 'First Party Collection/Use|||Action First-Party|||Collect on website',
#        'id': '22uq9xd7xpteykgy',
#        'answers': [{'text': "If you use our website, we may collect information about the browser you're using.",
#          'answer_start': 19},
#         {'text': 'If you use our website,', 'answer_start': 19},
#         {'text': 'If you use our website, we may collect',
#          'answer_start': 19}]},
#       {'question': 'Do you collect or use my information? If yes, then what type?',
#        'type': 'First Party Collection/Use|||Personal Information Type|||Computer information',
#        'id': '331acxv5d490yr2h',
#        'answers': [{'text': "browser you're using", 'answer_start': 80},
#         {'text': 'type of mobile device you are using, or the version of the operating system your computer or device is running',
#          'answer_start': 308},
#         {'text': "browser you're using.", 'answer_start': 80},
#         {'text': 'We might also collect the type of mobile device you are using, or the version of the operating system your computer or device is running.',
#          'answer_start': 282},
#         {'text': "information about the browser you're using. We might look at what site you came from, or what site you visit when you leave us.",
#          'answer_start': 58}]},
#       {'question': 'What are the choices or controls available to the users?',
#        'type': 'First Party Collection/Use|||Choice Type|||Dont use service/feature',
#        'id': '36cfo8lm4gsud848',
#        'answers': [{'text': 'If you use our website', 'answer_start': 19}]},
#       {'question': 'Does this website collect my information?',
#        'type': 'First Party Collection/Use|||Does/Does Not|||Does',
#        'id': 'i257saypjm0rz7mm',
#        'answers': [{'text': 'we may collect information',
#          'answer_start': 43}]},
#       {'question': 'Do they keep track of my online activities?',
#        'type': 'First Party Collection/Use|||Personal Information Type|||User online activities',
#        'id': '7rpyfhf24cn578nn',
#        'answers': [{'text': 'what site you came from, or what site you visit when you leave us',
#          'answer_start': 119},
#         {'text': 'We might look at how often you use the app and where you downloaded it.',
#          'answer_start': 420},
#         {'text': 'We might look at what site you came from, or what site you visit when you leave us.',
#          'answer_start': 102}]},
#       {'question': 'Does the website collect my data if I use their app?',
#        'type': 'First Party Collection/Use|||Action First-Party|||Collect in mobile app',
#        'id': 'x86vbod44jeo0ohi',
#        'answers': [{'text': 'our mobile app', 'answer_start': 197},
#         {'text': 'If you use our mobile app', 'answer_start': 186},
#         {'text': 'If you use our mobile app,', 'answer_start': 186},
#         {'text': 'If you use our mobile app, we may collect',
#          'answer_start': 186}]},
#       {'question': 'What types of location data do you collect?',
#        'type': 'First Party Collection/Use|||Personal Information Type|||Location',
#        'id': 'v0gl8tmqgf3825c4',
#        'answers': [{'text': 'GPS location', 'answer_start': 233},
#         {'text': 'we may collect your GPS location', 'answer_start': 213},
#         {'text': 'your GPS location', 'answer_start': 228}]},
#       {'question': "Does the company collect user's IP address and device IDs?",
#        'type': 'First Party Collection/Use|||Personal Information Type|||IP address and device IDs',
#        'id': 'h8km4p3ikxz3as5s',
#        'answers': [{'text': "device's unique identifier", 'answer_start': 254},
#         {'text': "your device's unique identifier.", 'answer_start': 249},
#         {'text': "your device's unique identifier", 'answer_start': 249}]}],
#      'index': 6,
#      'context': "Other information. If you use our website, we may collect information about the browser you're using. We might look at what site you came from, or what site you visit when you leave us. If you use our mobile app, we may collect your GPS location or your device's unique identifier. We might also collect the type of mobile device you are using, or the version of the operating system your computer or device is running. We might look at how often you use the app and where you downloaded it."},
#     {'qas': [{'question': 'Do you collect data about users explicitly?',
#        'type': 'First Party Collection/Use|||Collection Mode|||Explicit',
#        'id': 'qax0rss7sjc05rk3',
#        'answers': [{'text': 'We collect information directly from you.',
#          'answer_start': 42},
#         {'text': 'We collect information directly from you',
#          'answer_start': 42}]},
#       {'question': 'What scope does the user choice apply to?',
#        'type': 'First Party Collection/Use|||Choice Scope|||Collection',
#        'id': 'qdazwxll5rne3cqd',
#        'answers': [{'text': 'collect', 'answer_start': 45}]},
#       {'question': 'Do you provide choices to the users with regards to your data collection?',
#        'type': 'First Party Collection/Use|||Choice Type|||Dont use service/feature',
#        'id': '7p3tb3oh9hxgjq95',
#        'answers': [{'text': 'if you register', 'answer_start': 97}]},
#       {'question': "Does this website use information collected from the user's?",
#        'type': 'First Party Collection/Use|||Does/Does Not|||Does',
#        'id': '2so6kh6jphlu6vpd',
#        'answers': [{'text': 'We collect information in different ways.',
#          'answer_start': 0}]},
#       {'question': 'For what purpose do you use my data?',
#        'type': 'First Party Collection/Use|||Purpose|||Additional service/feature',
#        'id': 'gxtaxl1ctkgl5jzr',
#        'answers': [{'text': 'register for a promotion', 'answer_start': 104}]},
#       {'question': "Does the website collect user's information to provide basic services?",
#        'type': 'First Party Collection/Use|||Purpose|||Basic service/feature',
#        'id': '0a50xb181sb0rk20',
#        'answers': [{'text': 'buy tickets', 'answer_start': 132},
#         {'text': 'if you register for a promotion or buy tickets. We also collect information if you post a comment on our websites or ask us a question',
#          'answer_start': 97}]}],
#      'index': 7,
#      'context': 'We collect information in different ways. We collect information directly from you. For example, if you register for a promotion or buy tickets. We also collect information if you post a comment on our websites or ask us a question.'},
#     {'qas': [{'question': 'How do you collect my information for use?',
#        'type': 'First Party Collection/Use|||Collection Mode|||Implicit',
#        'id': '0gytx80fjr1joejd',
#        'answers': [{'text': 'passively.', 'answer_start': 32},
#         {'text': 'We collect information from you passively.',
#          'answer_start': 0},
#         {'text': 'information from you passively', 'answer_start': 11}]},
#       {'question': 'Will you give me choices for my data collection?',
#        'type': 'First Party Collection/Use|||Choice Scope|||Collection',
#        'id': '7x7t2o918uf9a7n7',
#        'answers': [{'text': 'collect', 'answer_start': 3}]},
#       {'question': 'In what ways do you obtain my information?',
#        'type': 'First Party Collection/Use|||Action First-Party|||Other',
#        'id': '5kzwjf4bcz3o087m',
#        'answers': [{'text': 'We use tracking tools like browser cookies and web beacons.',
#          'answer_start': 43}]},
#       {'question': 'Will you let me modify the privacy setting for your data usage?',
#        'type': 'First Party Collection/Use|||Choice Type|||Third-party privacy controls',
#        'id': '1l9ykq77bipy2te3',
#        'answers': [{'text': 'To learn more about these tools and to control them, please click here.',
#          'answer_start': 103}]},
#       {'question': 'Does this website collect my information?',
#        'type': 'First Party Collection/Use|||Does/Does Not|||Does',
#        'id': 'm56il4krxin3as7i',
#        'answers': [{'text': 'We collect information from you passively.',
#          'answer_start': 0}]},
#       {'question': 'Do you keep track of my information?',
#        'type': 'First Party Collection/Use|||Personal Information Type|||Cookies and tracking elements',
#        'id': 'lzjpbmmxqf1r8n8a',
#        'answers': [{'text': 'We use tracking tools like browser cookies and web beacons.',
#          'answer_start': 43},
#         {'text': 'We use tracking tools like browser cookies and web beacons',
#          'answer_start': 43}]},
#       {'question': 'What type of choice is applicable for first party data collection?',
#        'type': 'First Party Collection/Use|||Choice Type|||Other',
#        'id': '3yitikvqsdtkkzz0',
#        'answers': [{'text': 'To learn more about these tools and to control them, please click here.',
#          'answer_start': 103}]}],
#      'index': 8,
#      'context': 'We collect information from you passively. We use tracking tools like browser cookies and web beacons. To learn more about these tools and to control them, please click here.'},
#     {'qas': [{'question': 'What scope does the user choice apply to?',
#        'type': 'First Party Collection/Use|||Choice Scope|||Collection',
#        'id': 've59acnw3i3muu5n',
#        'answers': [{'text': 'We get information about you',
#          'answer_start': 0}]},
#       {'question': 'Do you receive my data from other companies? ',
#        'type': 'First Party Collection/Use|||Action First-Party|||Receive from other service/third-party (unnamed)',
#        'id': 'tjbe60dv9jk9tg57',
#        'answers': [{'text': 'We get information about you from third parties.',
#          'answer_start': 0},
#         {'text': 'We get information about you from third parties',
#          'answer_start': 0}]},
#       {'question': 'Do you ask for my contact information?',
#        'type': 'First Party Collection/Use|||Personal Information Type|||Contact',
#        'id': 'evaizj1aau1cawat',
#        'answers': [{'text': 'name and email address.', 'answer_start': 250},
#         {'text': 'This could include your name and email address.',
#          'answer_start': 226}]},
#       {'question': 'Do you provide choices to the users with regards to your data collection?',
#        'type': 'First Party Collection/Use|||Choice Type|||Dont use service/feature',
#        'id': 'cvfgtntnqnj9v4at',
#        'answers': [{'text': 'if you use an integrated social media feature on our websites or mobile applications',
#          'answer_start': 62}]},
#       {'question': 'Can you identify me via my data that you collect?',
#        'type': 'First Party Collection/Use|||Identifiability|||Identifiable',
#        'id': '6ztnn8yqoapmi29s',
#        'answers': [{'text': 'This could include your name and email address.',
#          'answer_start': 226}]},
#       {'question': "Does this website use information collected from the user's?",
#        'type': 'First Party Collection/Use|||Does/Does Not|||Does',
#        'id': 'fstxps538j3rhnbm',
#        'answers': [{'text': 'We get information about you',
#          'answer_start': 0}]},
#       {'question': 'Is my information collected for the purpose of providing additional service?',
#        'type': 'First Party Collection/Use|||Purpose|||Additional service/feature',
#        'id': 'xsy0v0g52e5r8i5i',
#        'answers': [{'text': 'integrated social media feature on our websites or mobile applications.',
#          'answer_start': 76}]},
#       {'question': 'Do they collect my social media data?',
#        'type': 'First Party Collection/Use|||Personal Information Type|||Social media data',
#        'id': 'gitab5v4is6i0fgy',
#        'answers': [{'text': 'Your activities on our sites and apps may be posted to the social media platforms.',
#          'answer_start': 274}]}],
#      'index': 9,
#      'context': 'We get information about you from third parties. For example, if you use an integrated social media feature on our websites or mobile applications. The third-party social media site will give us certain information about you. This could include your name and email address. Your activities on our sites and apps may be posted to the social media platforms.'},
#     {'qas': [{'question': 'What scope does the user choice or control apply to?',
#        'type': 'First Party Collection/Use|||Choice Scope|||Use',
#        'id': '9z8frxyndxqb0s7h',
#        'answers': [{'text': 'use', 'answer_start': 3}]},
#       {'question': "Does this website use information collected from the user's?",
#        'type': 'First Party Collection/Use|||Does/Does Not|||Does',
#        'id': 'demgyhqds4wpdrw0',
#        'answers': [{'text': 'We use information as disclosed and described here',
#          'answer_start': 0}]},
#       {'question': 'Why do you collect my data?',
#        'type': 'First Party Collection/Use|||Purpose|||Basic service/feature',
#        'id': 'n570ccsw2ouvw11i',
#        'answers': [{'text': 'confirm your registration for an event',
#          'answer_start': 159},
#         {'text': "We use information to respond to your requests or questions. For example, we might use your information to confirm your registration for an event or contest. If you give us your friend's information, we will only use it to provide services you requested.",
#          'answer_start': 52}]},
#       {'question': 'Why do you collect the my data?',
#        'type': 'First Party Collection/Use|||Purpose|||Additional service/feature',
#        'id': 'cohhoih0d3sab8lv',
#        'answers': [{'text': 'contest', 'answer_start': 201},
#         {'text': "to respond to your requests or questions. For example, we might use your information to confirm your registration for an event or contest. If you give us your friend's information, we will only use it to provide services you requested.",
#          'answer_start': 71}]}],
#      'index': 10,
#      'context': "We use information as disclosed and described here. We use information to respond to your requests or questions. For example, we might use your information to confirm your registration for an event or contest. If you give us your friend's information, we will only use it to provide services you requested."},
#     {'qas': [{'question': 'Does you collect my information to enhance or personalize my experience?',
#        'type': 'First Party Collection/Use|||Purpose|||Personalization/Customization',
#        'id': 'km4077l14103blrk',
#        'answers': [{'text': 'We use information to improve our products and services. We might use your information to customize your experience with us. This could include displaying content based upon your preferences.',
#          'answer_start': 0},
#         {'text': 'customize your experience with us. This could include displaying content based upon your preferences.',
#          'answer_start': 90}]},
#       {'question': 'Does this website collect my information?',
#        'type': 'First Party Collection/Use|||Does/Does Not|||Does',
#        'id': 'tz3729pxw9s1jiuj',
#        'answers': [{'text': 'We use information', 'answer_start': 0}]},
#       {'question': "Does the company use user's information for analytics or research?",
#        'type': 'First Party Collection/Use|||Purpose|||Analytics/Research',
#        'id': 'sdqd1esidn0crkl8',
#        'answers': [{'text': 'improve our products and services',
#          'answer_start': 22}]}],
#      'index': 11,
#      'context': 'We use information to improve our products and services. We might use your information to customize your experience with us. This could include displaying content based upon your preferences.'},
#     {'qas': [{'question': 'Do you use my information for research?',
#        'type': 'First Party Collection/Use|||Purpose|||Analytics/Research',
#        'id': '4uvmhyddyj5c8xyp',
#        'answers': [{'text': 'We use information to look at site trends and customer interests. We may use your information to make our website and products better.',
#          'answer_start': 0},
#         {'text': 'look at site trends and customer interests. We may use your information to make our website and products better',
#          'answer_start': 22}]},
#       {'question': 'Do you use my information?',
#        'type': 'First Party Collection/Use|||Does/Does Not|||Does',
#        'id': 'eapu92fm8s0vere5',
#        'answers': [{'text': 'We use information', 'answer_start': 0}]},
#       {'question': 'Do you receive information from other sources?',
#        'type': 'First Party Collection/Use|||Action First-Party|||Receive from other service/third-party (unnamed)',
#        'id': 'bw9bayufxrgoyz8g',
#        'answers': [{'text': 'We may combine information we get from you with information about you we get from third parties',
#          'answer_start': 135}]}],
#      'index': 12,
#      'context': 'We use information to look at site trends and customer interests. We may use your information to make our website and products better. We may combine information we get from you with information about you we get from third parties.'},
#     {'qas': [{'question': 'Will they use the data collected from me?',
#        'type': 'First Party Collection/Use|||Does/Does Not|||Does',
#        'id': 'jjwss8a6wmyyc9c3',
#        'answers': [{'text': 'We use information', 'answer_start': 0}]},
#       {'question': "Does the company use users' information for website/app operation?",
#        'type': 'First Party Collection/Use|||Purpose|||Service Operation and Security',
#        'id': '8e16joc3s041j2d2',
#        'answers': [{'text': 'security purposes. We may use information to protect our company, our customers, or our websites.',
#          'answer_start': 23},
#         {'text': 'We use information for security purposes. We may use information to protect our company, our customers, or our websites.',
#          'answer_start': 0}]},
#       {'question': 'Is my information secured and protected?',
#        'type': 'Data Security|||Security Measure|||Generic',
#        'id': 'j9pfbkdj2l2059t8',
#        'answers': [{'text': 'We use information for security purposes. We may use information to protect our company, our customers, or our websites.',
#          'answer_start': 0}]}],
#      'index': 13,
#      'context': 'We use information for security purposes. We may use information to protect our company, our customers, or our websites.'},
#     {'qas': [{'question': 'Does the choice related to first party data use or collection?',
#        'type': 'First Party Collection/Use|||Choice Scope|||Use',
#        'id': '5muku64b39y6esj6',
#        'answers': [{'text': 'use', 'answer_start': 3}]},
#       {'question': 'Will you give me control over your data collection or use?',
#        'type': 'First Party Collection/Use|||Choice Type|||Dont use service/feature',
#        'id': '0qx2h52bnfcm8jpq',
#        'answers': [{'text': "if you buy tickets from us we'll enroll you in our newsletter.",
#          'answer_start': 308}]},
#       {'question': "Does this website use information collected from the user's?",
#        'type': 'First Party Collection/Use|||Does/Does Not|||Does',
#        'id': '5ys4v44kbmln6jwr',
#        'answers': [{'text': 'We use information', 'answer_start': 0}]},
#       {'question': 'Will you use my information for marketing or promotional services?',
#        'type': 'First Party Collection/Use|||Purpose|||Marketing',
#        'id': '0djliniujzn5jbek',
#        'answers': [{'text': 'marketing purposes. For example, we might send you information about special promotions or offers. We might also tell you about new features or products. These might be our own offers or products, or third-party offers or products we think you might find interesting',
#          'answer_start': 23},
#         {'text': 'send you alerts regarding local events',
#          'answer_start': 453},
#         {'text': "We use information for marketing purposes. For example, we might send you information about special promotions or offers. We might also tell you about new features or products. These might be our own offers or products, or third-party offers or products we think you might find interesting. Or, for example, if you buy tickets from us we'll enroll you in our newsletter. We may use push notifications and your location information on our mobile apps to send you alerts regarding local events.",
#          'answer_start': 0},
#         {'text': "for marketing purposes. For example, we might send you information about special promotions or offers. We might also tell you about new features or products. These might be our own offers or products, or third-party offers or products we think you might find interesting. Or, for example, if you buy tickets from us we'll enroll you in our newsletter. We may use push notifications and your location information on our mobile apps to send you alerts regarding local events. To learn about your choices for these communications, read the choices section below.",
#          'answer_start': 19}]},
#       {'question': 'Do you use my information collected on your mobile app?',
#        'type': 'First Party Collection/Use|||Action First-Party|||Collect in mobile app',
#        'id': 'ltlm774f2zw1w8s9',
#        'answers': [{'text': 'our mobile apps', 'answer_start': 434}]},
#       {'question': "What types of user's information do you collect?",
#        'type': 'First Party Collection/Use|||Personal Information Type|||Location',
#        'id': 'xf7hbxx6u70tc1ra',
#        'answers': [{'text': 'your location information',
#          'answer_start': 405}]},
#       {'question': 'Does the website offer privacy controls to the users? ',
#        'type': 'First Party Collection/Use|||Choice Type|||Other',
#        'id': 'e7vxojqhem397cat',
#        'answers': [{'text': 'To learn about your choices for these communications, read the choices section below.',
#          'answer_start': 493}]},
#       {'question': 'What are the ways you are going to collect my data?',
#        'type': 'First Party Collection/Use|||Action First-Party|||Other',
#        'id': 'trwggemrergokf10',
#        'answers': [{'text': 'We use', 'answer_start': 0}]}],
#      'index': 14,
#      'context': "We use information for marketing purposes. For example, we might send you information about special promotions or offers. We might also tell you about new features or products. These might be our own offers or products, or third-party offers or products we think you might find interesting. Or, for example, if you buy tickets from us we'll enroll you in our newsletter. We may use push notifications and your location information on our mobile apps to send you alerts regarding local events. To learn about your choices for these communications, read the choices section below."},
#     {'qas': [{'question': 'Do you use my information?',
#        'type': 'First Party Collection/Use|||Does/Does Not|||Does',
#        'id': '09awi99xxn4c0u48',
#        'answers': [{'text': 'We use information', 'answer_start': 0}]},
#       {'question': "Does the website collect user's information to provide basic services?",
#        'type': 'First Party Collection/Use|||Purpose|||Basic service/feature',
#        'id': 'vzhxn3zpmocnznji',
#        'answers': [{'text': 'transactional communications. For example, we might send you emails about your account or a ticket purchase. We might also contact you about this policy or our website terms.',
#          'answer_start': 31},
#         {'text': 'to send you transactional communications. For example, we might send you emails about your account or a ticket purchase. We might also contact you about this policy or our website terms.',
#          'answer_start': 19}]},
#       {'question': 'Do you collect or use my information? If yes, then what type?',
#        'type': 'First Party Collection/Use|||Personal Information Type|||Contact',
#        'id': 'z4sqrw86gm7ko99j',
#        'answers': [{'text': 'to send you transactional communications.',
#          'answer_start': 19}]},
#       {'question': 'For what purpose do you use or collect my data?',
#        'type': 'First Party Collection/Use|||Purpose|||Service Operation and Security',
#        'id': 'h4gn7s4ngw9o4kwj',
#        'answers': [{'text': 'We use information to send you transactional communications. For example, we might send you emails about your account or a ticket purchase. We might also contact you about this policy or our website terms.',
#          'answer_start': 0}]},
#       {'question': 'What are the ways you are going to collect my data?',
#        'type': 'First Party Collection/Use|||Action First-Party|||Other',
#        'id': 'sso28sxr8xv9mq18',
#        'answers': [{'text': 'We use', 'answer_start': 0}]}],
#      'index': 15,
#      'context': 'We use information to send you transactional communications. For example, we might send you emails about your account or a ticket purchase. We might also contact you about this policy or our website terms.'},
#     {'qas': [{'question': 'Will they use the data collected from me?',
#        'type': 'First Party Collection/Use|||Does/Does Not|||Does',
#        'id': '661im2g3lxchkyvn',
#        'answers': [{'text': 'We use information', 'answer_start': 0}]},
#       {'question': 'Will you collect my data? If yes, how?',
#        'type': 'First Party Collection/Use|||Action First-Party|||Other',
#        'id': 'mlq3pu3mu4x4yehx',
#        'answers': [{'text': 'We use', 'answer_start': 0}]}],
#      'index': 16,
#      'context': 'We use information as otherwise permitted by law.'},
#     {'qas': [{'question': 'Can other parts of the company access my data? ',
#        'type': 'Third Party Sharing/Collection|||Third Party Entity|||Other part of company/affiliate',
#        'id': 'cibp9vhlf8qsmkpq',
#        'answers': [{'text': 'Live Nation family of companies. This may include Ticketmaster and Live Nation-owned or operated venues, for example.',
#          'answer_start': 82},
#         {'text': 'We will share information within the Live Nation family of companies. This may include Ticketmaster and Live Nation-owned or operated venues, for example.',
#          'answer_start': 45},
#         {'text': 'within the Live Nation family of companies',
#          'answer_start': 71}]},
#       {'question': 'Do you share my information with others?',
#        'type': 'Third Party Sharing/Collection|||Does/Does Not|||Does',
#        'id': '5kejkmepqpqyhngp',
#        'answers': [{'text': 'We will share information', 'answer_start': 45}]},
#       {'question': 'How does a third party receive my data from you?',
#        'type': 'Third Party Sharing/Collection|||Action Third Party|||Receive/Shared with',
#        'id': 'g5rmp3f867wiajxa',
#        'answers': [{'text': 'share information', 'answer_start': 53},
#         {'text': 'We will share information', 'answer_start': 45},
#         {'text': 'We may share information', 'answer_start': 0}]},
#       {'question': 'Who do you share my information with?',
#        'type': 'Third Party Sharing/Collection|||Third Party Entity|||Unnamed third party',
#        'id': 'ihq73j2y2j2mntwr',
#        'answers': [{'text': 'with third parties', 'answer_start': 25}]}],
#      'index': 17,
#      'context': 'We may share information with third parties. We will share information within the Live Nation family of companies. This may include Ticketmaster and Live Nation-owned or operated venues, for example.'},
#     {'qas': [{'question': "Does the company share user's information with a third party?",
#        'type': 'Third Party Sharing/Collection|||Third Party Entity|||Unnamed third party',
#        'id': '3wrxxi4qxk2sohwi',
#        'answers': [{'text': 'third parties who perform services on our behalf.',
#          'answer_start': 31}]},
#       {'question': "Does the company share user's data to provide basic services?",
#        'type': 'Third Party Sharing/Collection|||Purpose|||Basic service/feature',
#        'id': 'ajnvi1eids3vcmql',
#        'answers': [{'text': 'vendors who help us manage our online registration process or who fulfill your purchases',
#          'answer_start': 120}]},
#       {'question': 'Is my information shared with others?',
#        'type': 'Third Party Sharing/Collection|||Does/Does Not|||Does',
#        'id': '0j6ssoohdbr1d3dv',
#        'answers': [{'text': 'We will share information', 'answer_start': 0}]},
#       {'question': 'How can a third party see my information?',
#        'type': 'Third Party Sharing/Collection|||Action Third Party|||Receive/Shared with',
#        'id': '211jff5do0ad4xxa',
#        'answers': [{'text': 'share', 'answer_start': 8},
#         {'text': 'We will share information', 'answer_start': 0},
#         {'text': 'We will share', 'answer_start': 0}]},
#       {'question': 'Why do you share my data with others?',
#        'type': 'Third Party Sharing/Collection|||Purpose|||Additional service/feature',
#        'id': 't99e95xiwpx1a3p2',
#        'answers': [{'text': 'For example, we share information with vendors who help us manage our online registration process or who fulfill your purchases. Some vendors may be located outside of the United States.',
#          'answer_start': 81}]},
#       {'question': 'Does the company share my information with a third party?',
#        'type': 'Third Party Sharing/Collection|||Third Party Entity|||Named third party',
#        'id': '0xusplmj0l2ycc0v',
#        'answers': [{'text': 'third parties who perform services on our behalf',
#          'answer_start': 31}]}],
#      'index': 18,
#      'context': 'We will share information with third parties who perform services on our behalf. For example, we share information with vendors who help us manage our online registration process or who fulfill your purchases. Some vendors may be located outside of the United States.'},
#     {'qas': [{'question': 'Is my information shared with others? If yes, then who?',
#        'type': 'Third Party Sharing/Collection|||Third Party Entity|||Unnamed third party',
#        'id': 'ie055u6edwsodi49',
#        'answers': [{'text': 'business partners', 'answer_start': 35},
#         {'text': 'with our business partners', 'answer_start': 26}]},
#       {'question': "Does the user's choice applicable to third party collection of data?",
#        'type': 'Third Party Sharing/Collection|||Choice Scope|||Use',
#        'id': 'bqbw4nnxn26ycta6',
#        'answers': [{'text': 'share information', 'answer_start': 8}]},
#       {'question': 'What is the purpose of sharing my data with others?',
#        'type': 'Third Party Sharing/Collection|||Purpose|||Basic service/feature',
#        'id': 'dphrskb55qb9l4rg',
#        'answers': [{'text': 'provides or sponsors an event, or who operates a venue where we hold events',
#          'answer_start': 86}]},
#       {'question': 'Do you share my information with others?',
#        'type': 'Third Party Sharing/Collection|||Does/Does Not|||Does',
#        'id': 'cytru6thxu8kujvz',
#        'answers': [{'text': 'We will share information', 'answer_start': 0}]},
#       {'question': 'What are the ways third parties obtain our information?',
#        'type': 'Third Party Sharing/Collection|||Action Third Party|||Receive/Shared with',
#        'id': '7tpg762yksibqg4e',
#        'answers': [{'text': 'share', 'answer_start': 8},
#         {'text': 'We will share information', 'answer_start': 0},
#         {'text': 'We will share', 'answer_start': 0}]},
#       {'question': 'Who receives my information from this website?',
#        'type': 'Third Party Sharing/Collection|||Third Party Entity|||Named third party',
#        'id': 'yz4ly3f2yjmt4y2n',
#        'answers': [{'text': 'with our business partners.',
#          'answer_start': 26}]}],
#      'index': 19,
#      'context': 'We will share information with our business partners. This includes a third party who provides or sponsors an event, or who operates a venue where we hold events. Our partners use the information we give them as described in their privacy policies. You should read those polices to learn how they treat your information.'},
#     {'qas': [{'question': 'Does my data shared with others? If yes, who are they?',
#        'type': 'Third Party Sharing/Collection|||Third Party Entity|||Other',
#        'id': 'rv5gjlealyn84p52',
#        'answers': [{'text': 'government agency or investigatory body',
#          'answer_start': 211}]},
#       {'question': 'Will you share my information for law enforcement or fraud prevention?',
#        'type': 'Third Party Sharing/Collection|||Purpose|||Service operation and security',
#        'id': '6sv26m8oot97cvmr',
#        'answers': [{'text': 'when we are investigating potential fraud. This might include fraud we think has happened during a sweepstakes or promotion.',
#          'answer_start': 297},
#         {'text': 'we might also share information when we are investigating potential fraud. This might include fraud we think has happened during a sweepstakes or promotion.',
#          'answer_start': 265}]},
#       {'question': 'Will they disclose my data?',
#        'type': 'Third Party Sharing/Collection|||Does/Does Not|||Does',
#        'id': '9ouesazlchr4s060',
#        'answers': [{'text': 'We may share', 'answer_start': 0}]},
#       {'question': 'How can a third party see my information?',
#        'type': 'Third Party Sharing/Collection|||Action Third Party|||Receive/Shared with',
#        'id': '3eh101mzqtuu7qnv',
#        'answers': [{'text': 'share', 'answer_start': 7},
#         {'text': 'We may share information', 'answer_start': 0},
#         {'text': 'We may share', 'answer_start': 0}]},
#       {'question': 'If the law requires you to dislose my data, will you do that?',
#        'type': 'Third Party Sharing/Collection|||Purpose|||Legal requirement',
#        'id': 'ckyy8jsx9hy7sep2',
#        'answers': [{'text': 'respond to a court order or subpoena',
#          'answer_start': 147},
#         {'text': 'We may share information if we think we have to in order to comply with the law or to protect ourselves. For example, we will share information to respond to a court order or subpoena. We may also share it if a government agency or investigatory body requests. Or, we might also share information when we are investigating potential fraud. This might include fraud we think has happened during a sweepstakes or promotion.',
#          'answer_start': 0},
#         {'text': 'if we think we have to in order to comply with the law or to protect ourselves. For example, we will share information to respond to a court order or subpoena. We may also share it if a government agency or investigatory body requests.',
#          'answer_start': 25}]},
#       {'question': 'Who exactly do you share my information with?',
#        'type': 'Third Party Sharing/Collection|||Third Party Entity|||Named third party',
#        'id': 'zbj0a7s0jv883jep',
#        'answers': [{'text': 'government agency or investigatory body requests.',
#          'answer_start': 211}]}],
#      'index': 20,
#      'context': 'We may share information if we think we have to in order to comply with the law or to protect ourselves. For example, we will share information to respond to a court order or subpoena. We may also share it if a government agency or investigatory body requests. Or, we might also share information when we are investigating potential fraud. This might include fraud we think has happened during a sweepstakes or promotion.'},
#     {'qas': [{'question': 'What types of third parties collect my information?',
#        'type': 'Third Party Sharing/Collection|||Third Party Entity|||Other',
#        'id': '0xyeuoieqkgx0xbv',
#        'answers': [{'text': 'any successor to all or part of our business',
#          'answer_start': 30}]},
#       {'question': 'What happen to my data if your business is sold or transferred?',
#        'type': 'Third Party Sharing/Collection|||Purpose|||Merger/Acquisition',
#        'id': 'm6cp4rrussmytc62',
#        'answers': [{'text': 'if part of our business is sold',
#          'answer_start': 89},
#         {'text': 'For example, if part of our business is sold we may give our customer list as part of that transaction.',
#          'answer_start': 76}]},
#       {'question': 'Do you share my data with others? If yes, what is the type of data?',
#        'type': 'Third Party Sharing/Collection|||Personal Information Type|||Other',
#        'id': 'soe4079xcoicplsx',
#        'answers': [{'text': 'customer list', 'answer_start': 137}]},
#       {'question': "Does the company share user's information with third party companies?",
#        'type': 'Third Party Sharing/Collection|||Does/Does Not|||Does',
#        'id': 'zfs33xbad291df0r',
#        'answers': [{'text': 'We may share', 'answer_start': 0}]},
#       {'question': 'How does a third party receive my data from you?',
#        'type': 'Third Party Sharing/Collection|||Action Third Party|||Receive/Shared with',
#        'id': '0r2vexmdhtoyrqf7',
#        'answers': [{'text': 'share', 'answer_start': 7},
#         {'text': 'We may share information', 'answer_start': 0},
#         {'text': 'We may share', 'answer_start': 0}]},
#       {'question': 'Does the website mention the name of third parities, who gets my data?',
#        'type': 'Third Party Sharing/Collection|||Third Party Entity|||Named third party',
#        'id': 'tp669gz4wrn1fjt9',
#        'answers': [{'text': 'any successor to all or part of our business.',
#          'answer_start': 30},
#         {'text': 'with any successor to all or part of our business',
#          'answer_start': 25}]}],
#      'index': 21,
#      'context': 'We may share information with any successor to all or part of our business. For example, if part of our business is sold we may give our customer list as part of that transaction.'},
#     {'qas': [{'question': 'Do you share my information with others?',
#        'type': 'Third Party Sharing/Collection|||Does/Does Not|||Does',
#        'id': 'bqkq8ib4a9guvlvt',
#        'answers': [{'text': 'We may share your information',
#          'answer_start': 0}]},
#       {'question': 'How can a third party see my information?',
#        'type': 'Third Party Sharing/Collection|||Action Third Party|||Receive/Shared with',
#        'id': 'ekdalnj6d0ncr7ut',
#        'answers': [{'text': 'share', 'answer_start': 7},
#         {'text': 'We may share your information', 'answer_start': 0},
#         {'text': 'We may share', 'answer_start': 0}]},
#       {'question': 'What is the purpose of sharing my data with others?',
#        'type': 'Third Party Sharing/Collection|||Purpose|||Other',
#        'id': 'mm02kxgduqvz777g',
#        'answers': [{'text': 'for reasons not described in this policy. We will tell you before we do this.',
#          'answer_start': 30}]},
#       {'question': 'Do we have any choices for third party data collection? If yes, what are they?',
#        'type': 'Third Party Sharing/Collection|||Choice Type|||Other',
#        'id': 'c96q0jfr4i1xjkwg',
#        'answers': [{'text': 'We will tell you before we do this.',
#          'answer_start': 72}]}],
#      'index': 22,
#      'context': 'We may share your information for reasons not described in this policy. We will tell you before we do this.'},
#     {'qas': [{'question': "How do I opt out of the company's service?",
#        'type': 'User Choice/Control|||Choice Type|||Opt-out link',
#        'id': '2937mp0ykmntwi51',
#        'answers': [{'text': 'click here or follow the instructions in any promotional message you get from us.',
#          'answer_start': 153},
#         {'text': 'To stop receiving our promotional emails, click here or follow the instructions in any promotional message you get from us.',
#          'answer_start': 111},
#         {'text': 'You can opt out of receiving our marketing emails. To stop receiving our promotional emails, click here or follow the instructions in any promotional message you get from us.',
#          'answer_start': 60}]},
#       {'question': 'Does my choice applicable to first party use?',
#        'type': 'User Choice/Control|||Choice Scope|||First party use',
# ...
#     {'qas': [{'question': 'Does the company allow their employees to access my data?',
#        'type': 'Data Security|||Security Measure|||Data access limitation',
#        'id': 'vkwrmfuw8sc6l78k',
#        'answers': [{'text': 'Passwords are required to access your online account and help to protect your account information. Please keep this password confidential.',
#          'answer_start': 89}]},
#       {'question': "What security measures do you take while transferring the user's data?",
#        'type': 'Data Security|||Security Measure|||Secure data transfer',
#        'id': 'dshst62oa76i3nhk',
#        'answers': [{'text': 'Encryption technology, called Secure Sockets Layer (SSL), helps to protect personal information in certain areas of our websites during transport across the Internet. The presence of SSL encryption may be indicated by https in the browser URL or the image of a closed lock or solid key in the browser window. These indications may not be present in mobile services that use SSL.',
#          'answer_start': 228},
#         {'text': 'Encryption technology, called Secure Sockets Layer (SSL), helps to protect personal information in certain areas of our websites during transport across the Internet. The presence of SSL encryption may be indicated by https in the browser URL or the image of a closed lock or solid key in the browser window. These indications may not be present in mobile services that use SSL. For payment card information, we use secured networks, encryption or other protection of cardholder data, physical and technical access controls, monitoring and tests of security systems, and other information security practices to help to protect your information.',
#          'answer_start': 228}]},
#       {'question': 'Is the user authentication process secured?',
#        'type': 'Data Security|||Security Measure|||Secure user authentication',
#        'id': '0aw1gpku3w81c8sb',
#        'answers': [{'text': 'Passwords are required to access your online account and help to protect your account information.',
#          'answer_start': 89}]},
#       {'question': 'How do they secure their my data?',
#        'type': 'Data Security|||Security Measure|||Secure data storage',
#        'id': 'yh8so1gyymnnqeo7',
#        'answers': [{'text': 'Encryption technology, called Secure Sockets Layer (SSL), helps to protect personal information in certain areas of our websites during transport across the Internet.',
#          'answer_start': 228}]},
#       {'question': 'Is my information secured and protected?',
#        'type': 'Data Security|||Security Measure|||Generic',
#        'id': '66jn827020zfbc2w',
#        'answers': [{'text': 'monitoring and tests of security systems, and other information security practices to help to protect your information.',
#          'answer_start': 753}]}],
#      'index': 48,
#      'context': 'Here are some examples of security measures we use to protect your personal information: Passwords are required to access your online account and help to protect your account information. Please keep this password confidential. Encryption technology, called Secure Sockets Layer (SSL), helps to protect personal information in certain areas of our websites during transport across the Internet. The presence of SSL encryption may be indicated by https in the browser URL or the image of a closed lock or solid key in the browser window. These indications may not be present in mobile services that use SSL. For payment card information, we use secured networks, encryption or other protection of cardholder data, physical and technical access controls, monitoring and tests of security systems, and other information security practices to help to protect your information.'},
#     {'qas': [{'question': 'How do they secure my data?',
#        'type': 'Data Security|||Security Measure|||Other',
#        'id': '6gljs7uzvk30xyrp',
#        'answers': [{'text': 'To learn more about measures you can take to protect the security of your personal information, please click here.',
#          'answer_start': 0}]}],
#      'index': 49,
#      'context': 'To learn more about measures you can take to protect the security of your personal information, please click here.'},
#     {'qas': [{'question': "What is the company's policy towards children?",
#        'type': 'International and Specific Audiences|||Audience Type|||Children',
#        'id': 'xnnvrg4yi0ky4wwg',
#        'answers': [{'text': 'How Does Walmart Protect the Privacy of Children Online? Our websites and mobile services are intended for a general audience and are not directed to children.',
#          'answer_start': 0},
#         {'text': 'are not directed to children.', 'answer_start': 130}]}],
#      'index': 50,
#      'context': 'How Does Walmart Protect the Privacy of Children Online? Our websites and mobile services are intended for a general audience and are not directed to children.'},
#     {'qas': [{'question': 'Does the company collect or protect information from children?',
#        'type': 'International and Specific Audiences|||Audience Type|||Children',
#        'id': 'vcpwql98uboxgk0i',
#        'answers': [{'text': "We recognize the importance of protecting children's online privacy. Our websites and mobile services are intended for a general audience and are not directed to children. In order to protect the privacy of children, Walmart websites and mobile services knowingly collect personal information from children under the age of 13 only with prior parental consent or as permitted by law. Please Contact Us if you believe we may have collected information from your child through our websites or mobile services and we will work to delete it.",
#          'answer_start': 0}]}],
#      'index': 51,
#      'context': "We recognize the importance of protecting children's online privacy. Our websites and mobile services are intended for a general audience and are not directed to children. In order to protect the privacy of children, Walmart websites and mobile services knowingly collect personal information from children under the age of 13 only with prior parental consent or as permitted by law. Please Contact Us if you believe we may have collected information from your child through our websites or mobile services and we will work to delete it."},
#     {'qas': [{'question': 'Do you have special provisions for specific audiences?',
#        'type': 'International and Specific Audiences|||Audience Type|||Other',
#        'id': 'ieskgp1y8uu8onzt',
#        'answers': [{'text': 'We have additional specific notices for our personal information practices related to some of our specialized operations. For example: Our Health Wellness operations (Pharmacy and Vision Center) have a specific Notice of Privacy Practices for its information practices related to health information. Walmart makes a variety of financial products and services available to you, either directly or in connection with business partners. A description of privacy protections related to financial products and services is available here. This policy applies to customer personal information Walmart collects in the United States and Puerto Rico. Walmart maintains separate privacy policies applicable to its international operations.',
#          'answer_start': 0}]},
#       {'question': 'Is any difference when the policy applys to citizens from other countries?',
#        'type': 'International and Specific Audiences|||Audience Type|||Citizens from other countries',
#        'id': '4i4al6sap9u0tt1v',
#        'answers': [{'text': 'Walmart maintains separate privacy policies applicable to its international operations.',
#          'answer_start': 641}]}],
#      'index': 53,
#      'context': 'We have additional specific notices for our personal information practices related to some of our specialized operations. For example: Our Health Wellness operations (Pharmacy and Vision Center) have a specific Notice of Privacy Practices for its information practices related to health information. Walmart makes a variety of financial products and services available to you, either directly or in connection with business partners. A description of privacy protections related to financial products and services is available here. This policy applies to customer personal information Walmart collects in the United States and Puerto Rico. Walmart maintains separate privacy policies applicable to its international operations.'},
#     {'qas': [{'question': 'What do California residents notice?',
#        'type': 'International and Specific Audiences|||Audience Type|||Californians',
#        'id': '21j1j7gdr7oqljf3',
#        'answers': [{'text': 'What Are Your California Privacy Rights? Our Privacy Policy describes how we share information for marketing purposes. The Policy and rights apply to all customers, including California residents.',
#          'answer_start': 0},
#         {'text': 'The Policy and rights apply to all customers, including California residents.',
#          'answer_start': 119}]}],
#      'index': 57,
#      'context': 'What Are Your California Privacy Rights? Our Privacy Policy describes how we share information for marketing purposes. The Policy and rights apply to all customers, including California residents.'},
#     {'qas': [{'question': 'What is the data practice regarding to Californian users?',
#        'type': 'International and Specific Audiences|||Audience Type|||Californians',
#        'id': 'f5o0f3dgg5j7rwcs',
#        'answers': [{'text': 'Our Privacy Policy describes how we share information for marketing purposes. The Policy and rights apply to all customers, including California residents: We share personal information with others outside of Walmart for direct marketing of their products only if we have your affirmative consent (opt in). See "How Do We Share Your Personal Information Outside Walmart?" We share personal information with other businesses within our corporate family, such as Sam\'s Club and Vudu. See "How Do We Use Your Personal Information?"',
#          'answer_start': 0},
#         {'text': 'The Policy and rights apply to all customers, including California residents:',
#          'answer_start': 78}]},
#       {'question': 'Does the website mention the name of third parities, who gets my data?',
#        'type': 'Third Party Sharing/Collection|||Third Party Entity|||Unnamed third party',
#        'id': 'x32xf9j3v5lh4t4p',
#        'answers': [{'text': 'others outside of Walmart for direct marketing of their products',
#          'answer_start': 191}]},
#       {'question': 'Do I have choice for my data collected or used by a third party?',
#        'type': 'Third Party Sharing/Collection|||Choice Scope|||Collection',
#        'id': 'siia02zfjyh26xik',
#        'answers': [{'text': 'share', 'answer_start': 36}]},
#       {'question': 'Do you share my information with others for promotional services?',
#        'type': 'Third Party Sharing/Collection|||Purpose|||Marketing',
#        'id': 'dp6882lrfrkwc3mu',
#        'answers': [{'text': 'for marketing purposes', 'answer_start': 54}]},
#       {'question': 'Do the third parties receive my personal data from you?',
#        'type': 'Third Party Sharing/Collection|||Personal Information Type|||Generic personal information',
#        'id': 'achdp0aibgsyybhe',
#        'answers': [{'text': 'personal information', 'answer_start': 165},
#         {'text': 'personal information', 'answer_start': 381}]},
#       {'question': 'What is the opt-in choice for data sharing?',
#        'type': 'Third Party Sharing/Collection|||Choice Type|||Opt-in',
#        'id': '835iiho1dyubm983',
#        'answers': [{'text': 'only if we have your affirmative consent (opt in)',
#          'answer_start': 256}]},
#       {'question': 'Is my information shared with others?',
#        'type': 'Third Party Sharing/Collection|||Does/Does Not|||Does',
#        'id': 'p6v0di2l84fwqygp',
#        'answers': [{'text': 'we share information', 'answer_start': 33},
#         {'text': 'We share personal information', 'answer_start': 372}]},
#       {'question': 'How can a third party see my information?',
#        'type': 'Third Party Sharing/Collection|||Action Third Party|||Receive/Shared with',
#        'id': 'xhr0mgzf5vlytwvb',
#        'answers': [{'text': 'share', 'answer_start': 36},
#         {'text': 'share', 'answer_start': 375}]},
#       {'question': 'Do you share my information with your affiliates or subsidiaries?',
#        'type': 'Third Party Sharing/Collection|||Third Party Entity|||Other part of company/affiliate',
#        'id': 'a2tvhlnayiwl0hx9',
#        'answers': [{'text': 'other businesses within our corporate family,',
#          'answer_start': 407}]}],
#      'index': 58,
#      'context': 'Our Privacy Policy describes how we share information for marketing purposes. The Policy and rights apply to all customers, including California residents: We share personal information with others outside of Walmart for direct marketing of their products only if we have your affirmative consent (opt in). See "How Do We Share Your Personal Information Outside Walmart?" We share personal information with other businesses within our corporate family, such as Sam\'s Club and Vudu. See "How Do We Use Your Personal Information?"'},
#     {'qas': [{'question': 'For what type of policy changes, I will be notified?',
#        'type': 'Policy Change|||Change Type|||Privacy relevant change',
#        'id': 'y6146o0wk80xw0am',
#        'answers': [{'text': 'How Will I Know if this Policy Changes? We will provide additional notice of significant updates.',
#          'answer_start': 0},
#         {'text': 'We will provide additional notice of significant updates',
#          'answer_start': 40},
#         {'text': 'significant updates', 'answer_start': 77}]},
#       {'question': 'What policy changes are being informed to the users?',
#        'type': 'Policy Change|||Change Type|||Non-privacy relevant change',
#        'id': '6yjzwxk9p1cy851t',
#        'answers': [{'text': 'We will post the date our Policy was last updated at the top of the Privacy Policy.',
#          'answer_start': 98}]},
#       {'question': 'How do you inform all the users upon policy changes?',
#        'type': 'Policy Change|||Notification Type|||General notice in privacy policy',
#        'id': 'bberrd9thmylaqoh',
#        'answers': [{'text': 'We will post the date our Policy was last updated at the top of the Privacy Policy.',
#          'answer_start': 98}]}],
#      'index': 60,
#      'context': 'How Will I Know if this Policy Changes? We will provide additional notice of significant updates. We will post the date our Policy was last updated at the top of the Privacy Policy.'},
#     {'qas': [{'question': 'Will they inform me if they make privacy relevant changes in their policy?',
#        'type': 'Policy Change|||Change Type|||Privacy relevant change',
#        'id': 'pun7flxvyijoz9qu',
#        'answers': [{'text': 'We will provide additional notice of significant updates.',
#          'answer_start': 58}]},
#       {'question': 'How does this website inform users about their policy changes?',
#        'type': 'Policy Change|||Notification Type|||General notice in privacy policy',
#        'id': '5p5gmonpo3hfn3sn',
#        'answers': [{'text': 'We will post the date our Policy was last updated at the top of the Privacy Policy.',
#          'answer_start': 116}]}],
#      'index': 61,
#      'context': 'Please check our Privacy Policy periodically for changes. We will provide additional notice of significant updates. We will post the date our Policy was last updated at the top of the Privacy Policy.'}],
#    'file_name': '348_walmart.com.html'}]}

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 chunks
#
# NameError: name 'chunks' is not defined
